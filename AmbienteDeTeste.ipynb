# %% [markdown]
# <a href="https://colab.research.google.com/github/rfps09/Colab-Backup/blob/main/AmbienteDeTeste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Gerando Markov com função:
# Hearbeat values range from 0 to 1; we will divide into quantiles and see which bin each value belongs to
# and what the probability is to transfer from 1 bin to other
# i.e if 1 value is in bin 1 and the next value is in bin 5, what is the probability of transferring from
# bin 1 to 5
# correlation matrix of probabilities is markov transition field
def get_quantiles(min_value=0, max_val=1, k=10):
    c = (max_val - min_value)/k
    b = min_value + c
    d = []
    for i in range(1, k):
        d.append(b)
        b += c
    d.append(max_val)
    return d

quantiles = get_quantiles()

def value_to_quantile(x):
    for i, k in enumerate(quantiles):
        if x <= k:
            return i
    return 0

def get_mtf(x, size=10):
    q = np.vectorize(value_to_quantile)(x)
    r = np.zeros((q.shape[0], q.shape[0]))
    y = np.zeros((size, size))
    for i in range(x.shape[0] - 1):
        y[q[i], q[i + 1]] += 1
    y = y / y.sum(axis=1, keepdims=True)
    y[np.isnan(y)] = 0
   
    for i in range(r.shape[0]):
        for j in range(r.shape[1]):
            r[i, j] = y[q[i], q[j]]
    return r / 5. - 1

# %%
import numpy as np
import matplotlib.pyplot as plt

serie = np.genfromtxt('drive/MyDrive/TensorFlow/DataSets/HeartBeat/mitbih_train.csv', delimiter=',', max_rows=1);

matriz = get_mtf(serie)

plt.imshow(matriz, cmap='rainbow', origin='lower')

plt.show()

# %%
# !pip install pyts

# %%
import numpy as np
import matplotlib.pyplot as plt
from pyts.image import MarkovTransitionField

serie = np.reshape(serie,(1,-1))
matriz = MarkovTransitionField(n_bins=8).fit_transform(serie)

print(matriz.shape)

plt.imshow(matriz[0], cmap='rainbow', origin='lower')

plt.show()

# %%
# !unzip 'drive/MyDrive/TensorFlow/DataSets/archive(1).zip' -d 'drive/MyDrive/TensorFlow/DataSets/teste/'
# Out:
# Archive:  drive/MyDrive/TensorFlow/DataSets/archive(1).zip
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_1.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_106.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_109.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_113.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_114.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_116.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_118.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_119.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_124.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_140.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_147.jpg
#   inflating: drive/MyDrive/TensorFlow/DataSets/teste/test/cats/cat_156.jpg
# ...
